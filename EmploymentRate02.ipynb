# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\rowla\4307\Week02\Lab\NEW02_98-401-X2016044_BRITISH_COLUMBIA_English_CSV_data.csv")

# %%
df
# Out:
#        Geocode  Employment Rate
# 0     59010238             59.7
# 1     59010239             67.7
# 2     59010240             68.9
# 3     59010241             64.0
# 4     59010242             68.4
# 5     59010228             46.5
# 6     59010229             71.4
# 7     59010230             58.4
# 8     59010231             74.0
# 9     59010232             58.9
# 10    59010233             68.5
# 11    59010234             75.9
# 12    59010217             58.8
# 13    59010218             71.1
# 14    59010219             80.0
# 15    59010220             67.1
# 16    59010221             62.3
# 17    59010222             69.0
# 18    59010223             68.4
# 19    59010226             79.4
# 20    59010255             65.7
# 21    59010224             75.4
# 22    59010227             69.5
# 23    59010248             64.6
# 24    59010254             62.8
# 25    59010210             56.2
# 26    59010211             42.2
# 27    59010212             57.8
# ...

# %%
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from pylab import rcParams
import seaborn as sb

# %%
df2 = df['Employment Rate']
plt.hist(df2)

plt.savefig(r"C:\Users\rowla\4307\Week02\Lab\EmploymentRate.jpeg", dpi=None, facecolor='w', edgecolor='w',
        orientation='portrait', papertype=None, format=None,
        transparent=False, bbox_inches=None, pad_inches=0.1,
        frameon=None, metadata=None)
